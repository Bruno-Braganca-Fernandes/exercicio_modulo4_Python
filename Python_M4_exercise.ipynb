# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Módulo** | Python: Arquivos & Funções
# Caderno de **Exercícios**<br>
# Professor [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Leitura;</li>
#   <li>Escrita;</li>
#   <li>Funções;</li>
#   <li>Escopo.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Exercícios**

# %% [markdown]
# ## 0\. Preparação do ambiente

# %% [markdown]
# Neste exercício vamos trabalhar com os arquivos de csv e texto definidos abaixo. Execute cada uma das células de código para escrever os arquivos na sua máquina virtual.

# %% [markdown]
# * **carros.csv**: arquivo csv com informações sobre carros (venda, manutenção, portas, etc.).

# %%
# %%writefile carros.csv
# id,valor_venda,valor_manutencao,portas,pessoas,porta_malas
# 1,vhigh,med,2,2,small
# 2,med,vhigh,2,2,small
# 3,low,vhigh,2,2,small
# 4,low,high,2,2,small
# 5,low,high,2,2,small
# 6,low,high,4,4,big
# 7,low,high,4,4,big
# 8,low,med,2,2,small
# 9,low,med,2,2,small
# 10,low,med,2,2,small
# 11,low,med,4,4,big
# 12,low,low,2,2,small
# 13,low,low,4,4,small
# 14,low,low,4,4,med
# Out:
# Overwriting carros.csv

# %% [markdown]
# * **musica.txt**: arquivo texto com a letra da música Roda Viva do Chico Buarque.

# %%
# %%writefile musica.txt
# Roda Viva
# Chico Buarque
#
# Tem dias que a gente se sente
# Como quem partiu ou morreu
# A gente estancou de repente
# Ou foi o mundo então que cresceu
# A gente quer ter voz ativa
# No nosso destino mandar
# Mas eis que chega a roda viva
# E carrega o destino pra lá
#
# Roda mundo, roda-gigante
# Roda moinho, roda pião
#
# O tempo rodou num instante
# Nas voltas do meu coração
# A gente vai contra a corrente
# Até não poder resistir
# Na volta do barco é que sente
# O quanto deixou de cumprir
# Faz tempo que a gente cultiva
# A mais linda roseira que há
# Mas eis que chega a roda viva
# E carrega a roseira pra lá
#
# Roda mundo, roda-gigante
# Roda moinho, roda pião
# Out:
# Overwriting musica.txt

# %% [markdown]
# ---

# %% [markdown]
# ## 1\. Funções para arquivo csv

# %% [markdown]
# Complete a função abaixo para extrair uma coluna do arquivo csv em uma lista. Os elementos devem ter o tipo de dado correto.

# %%
def extrai_coluna_csv(nome_arquivo: str, indice_coluna: int, tipo_dado: str):

  coluna = []

  with open(file=nome_arquivo, mode='r', encoding='utf-8') as conteudo:
    
    conteudo.readline()
    
    for linha in conteudo:
      linha_limpa = linha.strip()
      valores = linha_limpa.split(',')
      valor_coluna = valores[indice_coluna]

      valor_convertido = None

      if tipo_dado == 'str':
        valor_convertido = str(valor_coluna)
      elif tipo_dado == 'int':
        valor_convertido = int(valor_coluna)

      if valor_convertido is not None:
        coluna.append(valor_convertido)

  return coluna

# %% [markdown]
# Você pode testar a função com os códigos abaixo.

# %%
# extrair a coluna valor_venda
valor_venda = extrai_coluna_csv(nome_arquivo='./carros.csv', indice_coluna=1, tipo_dado='str')
print(valor_venda) # deve retornar ['vhigh', 'med', 'low', ...]
# Out:
# ['valor_venda', 'vhigh', 'med', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low', 'low']

# %%
# extrair a coluna pessoas
pessoas = extrai_coluna_csv(nome_arquivo='./carros.csv', indice_coluna=4, tipo_dado='int')
print(pessoas) # deve retornar [2, 2, 2, ...]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 2
#       1 # extrair a coluna pessoas
# ----> 2 pessoas = extrai_coluna_csv(nome_arquivo='./carros.csv', indice_coluna=4, tipo_dado='int')
#       3 print(pessoas) # deve retornar [2, 2, 2, ...]
#
# Cell In[18], line 16, in extrai_coluna_csv(nome_arquivo, indice_coluna, tipo_dado)
#      14   valor_convertido = str(valor_coluna)
#      15 elif tipo_dado == 'int':
# ---> 16   valor_convertido = int(valor_coluna)
#      18 if valor_convertido is not None:
#      19   coluna.append(valor_convertido)
#
# ValueError: invalid literal for int() with base 10: 'pessoas'

# %% [markdown]
# ---

# %% [markdown]
# ## 2\. Funções para arquivo txt

# %% [markdown]
# Complete a função abaixo para extrair uma as palavras de uma linha do arquivo txt em uma lista.

# %%
def extrai_linha_txt(nome_arquivo: str, numero_linha: int):

  palavras_linha = []

  # leia o arquivo com o comando 'with' utilizando o parametro 'nome_arquivo'
  # extraia a linha do arquivo utilizando o parametro 'numero_linha'
  # quebre a linha em palavras com o comando split, note que o separador é um espaço ' '

  return palavras_linha

# %% [markdown]
# Você pode testar a função com os códigos abaixo.

# %%
linha10 = extrai_linha_txt(nome_arquivo='./musica.txt', numero_linha=10)
print(linha10) # deve retornar ['Mas', 'eis', 'que', 'chega', 'a', 'roda', 'viva']

# %% [markdown]
# ---
